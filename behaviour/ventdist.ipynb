# %%
import pandas as pd

# %%
vd = pd.read_csv("behavioural_data/result_5_ventral_distance0.csv")

# %%
vd.head()
# Out:
#    Unnamed: 0  ListName   final_y   final_x  cell_type  leading_cell  \
# 0           0         0  0.050611 -0.807993          0             0
# 1           0         1 -0.184320 -0.807925          0             0
# 2           0         2  0.132494 -0.511472          0             0
# 3           0         3 -0.144941 -0.518541          0             0
# 4           0         4  0.125330 -0.282063          0             0
#
#    experimentType  leader_autonomousMag  leader_De  \
# 0             2.0          1.111110e-07   0.000066
# 1             2.0          1.111110e-07   0.000066
# 2             2.0          1.111110e-07   0.000066
# 3             2.0          1.111110e-07   0.000066
# 4             2.0          1.111110e-07   0.000066
#
#    leader_interactionThreshold  ...  CEwidth  middle_zone_height   Nc  \
# 0                          1.0  ...      0.4                 0.5  6.0
# 1                          1.0  ...      0.4                 0.5  6.0
# ...

# %%
vd_leader = vd.query("leading_cell == 1")

# %%
vd_leader.shape
# Out:
# (77758, 24)

# %%
vd_leader.to_csv('behavioural_data/ventral_dist_leaders_only.csv')
