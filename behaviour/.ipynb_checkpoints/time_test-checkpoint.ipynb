# %%
import pandas as pd

# %%
speed_data = pd.read_csv('speed_results1.csv')

# %%
speed_data.head()
# Out:
#    Unnamed: 0  PMZcellspeed  Followercellspeed  Leadercellspeed  \
# 0           0      2.754457           8.584518         7.847642
# 1           0      2.878683                NaN         7.272481
# 2           0      2.146084           7.818439        10.431964
# 3           0      2.361459                NaN         8.157295
# 4           0      3.120770                NaN         8.174469
#
#    experimentType  leader_autonomousMag  leader_De  leader_k  \
# 0             5.0              0.000002    0.00003      0.01
# 1             2.0              0.000002    0.00003      0.01
# 2             6.0              0.000002    0.00003      0.01
# 3             2.0              0.000002    0.00003      0.01
# 4             2.0              0.000002    0.00003      0.01
#
#    leader_interactionThreshold  follower_autonomousMag  follower_De  \
# 0                          1.0                0.000001      0.00003
# 1                          1.0                0.000001      0.00003
# ...

# %%
control = speed_data.query("experimentType == 1")
all_leader = speed_data.query("experimentType == 2")
all_follower = speed_data.query("experimentType == 3")
