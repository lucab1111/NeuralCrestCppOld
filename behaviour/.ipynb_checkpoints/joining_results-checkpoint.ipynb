# %%
import pandas as pd

# %%
overtake_res = pd.read_csv('overtake_counts.csv')

# %%
overtake_res.head()
# Out:
#    Unnamed: 0  CEwidth                                        Param_Combo  \
# 0           0      0.4  lk_0.01_lDe_2.9999999999999997e-05_laM_2e-06_l...
# 1           0      0.4  lk_0.01_lDe_2.9999999999999997e-05_laM_2e-06_l...
# 2           0      0.4  lk_0.01_lDe_2.9999999999999997e-05_laM_2e-06_l...
# 3           0      0.4  lk_0.01_lDe_2.9999999999999997e-05_laM_2e-06_l...
# 4           0      0.4  lk_0.01_lDe_2.9999999999999997e-05_laM_2e-06_l...
#
#    chainShape  experimentType  follower_De  follower_a  follower_k  \
# 0         3.0             2.0      0.00003    0.000001        0.01
# 1         3.0             1.0      0.00003    0.000001        0.01
# 2         3.0             5.0      0.00003    0.000001        0.01
# 3         3.0             3.0      0.00003    0.000001        0.01
# 4         3.0             5.0      0.00003    0.000001        0.01
#
#    follower_overtakes  leader_De  ...  leader_k  leader_overtakes  \
# ...

# %%
finpos_res = pd.read_csv('final_position_results.csv')

# %%
finpos_res.head()
# Out:
#    Unnamed: 0  lowest_y  corresponding_x  experimentType  \
# 0           0  -1.50055        -0.040777             2.0
# 1           0  -1.70147         0.047016             1.0
# 2           0  -1.23928         0.048006             5.0
# 3           0  -1.40455         0.124360             3.0
# 4           0  -1.47146        -0.068413             5.0
#
#    leader_autonomousMag  leader_De  leader_k  leader_interactionThreshold  \
# 0              0.000002    0.00003      0.01                          1.0
# 1              0.000002    0.00003      0.01                          1.0
# 2              0.000002    0.00003      0.01                          1.0
# 3              0.000002    0.00003      0.01                          1.0
# 4              0.000002    0.00003      0.01                          1.0
#
#    follower_autonomousMag  follower_De  ...  follower_interactionThreshold  \
# 0                0.000001      0.00003  ...                            1.0
# ...

# %%
finpos_res.columns
# Out:
# Index(['Unnamed: 0', 'lowest_y', 'corresponding_x', 'experimentType',
#        'leader_autonomousMag', 'leader_De', 'leader_k',
#        'leader_interactionThreshold', 'follower_autonomousMag', 'follower_De',
#        'follower_k', 'follower_interactionThreshold',
#        'leader_gradientSensitivity', 'follower_gradientSensitivity',
#        'PMZheight', 'middle_zone_height', 'Nc', 'CEwidth', 'parameter_key',
#        'filename', 'chainShape'],
#       dtype='object')

# %%
finpos_res['new_param_key'] ==  finpos_res['leader_autonomousMag'] + '_' + \
                                finpos_res['leader_De'] + '_' + \
                                finpos_res['leader_k'] + '_' + \
                                finpos_res['leader_interactionThreshold'] + '_' + \
                                finpos_res['follower_autonomousMag'] + '_' + \
                                finpos_res['follower_De'] + '_' + \
                                finpos_res['follower_k'] + '_' + \
